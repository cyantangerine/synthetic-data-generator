# %% [markdown]
# <div align="center">
# <p align="center">
#
#
# # 🚀 Synthetic Data Generator
#
# </p>
# </div>
#
# The Synthetic Data Generator (SDG) is a specialized framework designed to generate high-quality structured tabular data. It incorporates a wide range of single-table, multi-table data synthesis algorithms and LLM-based synthetic data generation models.
#
# Synthetic data, generated by machines using real data, metadata, and algorithms, does not contain any sensitive information, yet it retains the essential characteristics of the original data. There is no direct correlation between synthetic data and real data, making it exempt from privacy regulations such as GDPR and ADPPA. This eliminates the risk of privacy breaches in practical applications.

# %%
# install dependencies
# !pip install git+https://github.com/hitsz-ids/synthetic-data-generator.git
# !pip install table_evaluator
# !pip install joblib==1.3.2

# %% [markdown]
# We demonstrate with a single table data synthetic example.

# %%
from sdgx.data_connectors.csv_connector import CsvConnector
from sdgx.models.ml.single_table.ctgan import CTGANSynthesizerModel
from sdgx.synthesizer import Synthesizer
from sdgx.data_loader import DataLoader
from sdgx.data_models.metadata import Metadata
# Out:
# C:\Users\Elvin\Desktop\GitHub\mysdg\synthetic-data-generator\sdgx\models\ml\single_table\ctgan.py:23: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm import autonotebook as tqdm

# %% [markdown]
# # 1. Load data and understand the data
#
# The demo data set for this demonstration is a risk control data set used to predict whether an individual will default on a loan. This dataset contains the following features:
#
# | Column name | Meaning |
# |-----------------------|-----------------------|
# | loan_id | loan ID |
# | user_id | user ID |
# | total_loan | Total loan amount |
# | year_of_loan | Loan period |
# ...

# %%
# download the example dataset
import os 
import requests

def download_file(url, path):
    response = requests.get(url)
    if response.status_code == 200:
        with open(path, 'wb') as file:
            file.write(response.content)
        print(f"File downloaded successfully to {path}")
    else:
        print(f"Failed to download file from {url}")
dataset_url = "https://raw.githubusercontent.com/aialgorithm/Blog/master/projects/一文梳理风控建模全流程/train_internet.csv"

if not os.path.exists("train_internet.csv"):
    download_file(dataset_url, "train_internet.csv")

# %% [markdown]
# This code shows the process of loading real data:

# %%
from pathlib import Path
file_path = './train_internet.csv'
path_obj = Path(file_path)

# Create a data connector and data loader for csv data
data_connector = CsvConnector(path=path_obj)
data_loader = DataLoader(data_connector)

# %% [markdown]
# # 2. Create synthetic data generation workflow
#
# Below we will use SDG to create a data synthetic workflow. This workflow includes steps such as automated metadata identification, which will help generate high-quality synthetic data:
#
# Firstly, we need to create a metadata object. SDG provides automated metadata identification functions that can extract key information from existing data sources, such as data type, data range, data distribution, etc.
# For more info, you can read the metadata notebook. You can also specify the categorical columns encoder in it. Now for this example we use default one-hot encoder.

# %%
loan_metadata = Metadata.from_dataloader(data_loader)
# Automatically infer discrete columns
loan_metadata.discrete_columns
# Out:
# 2024-12-17 20:23:20.471 | INFO     | sdgx.data_models.metadata:from_dataloader:333 - Inspecting metadata...
# 2024-12-17 20:23:22.492 | INFO     | sdgx.data_models.metadata:update_primary_key:564 - Primary Key updated: {'user_id', 'loan_id'}.
# {'class',
#  'earlies_credit_mon',
#  'employer_type',
#  'industry',
#  'issue_date',
#  'sub_class',
#  'work_type',
#  'work_year'}

# %% [markdown]
# After the model definition is completed, we can use SDG to generate synthetic data.

# %%
# Initialize synthesizer, use CTGAN model
synthesizer = Synthesizer(
    metadata= loan_metadata,
    model=CTGANSynthesizerModel(epochs=8),
    data_connector=data_connector,
)
# Out:
# 2024-12-17 20:25:58.475 | INFO     | sdgx.synthesizer:__init__:109 - Using data processors: ['specificcombinationtransformer', 'fixedcombinationtransformer', 'nonvaluetransformer', 'outliertransformer', 'emailgenerator', 'chnpiigenerator', 'intvalueformatter', 'datetimeformatter', 'constvaluetransformer', 'positivenegativefilter', 'emptytransformer', 'columnordertransformer']

# %% [markdown]
# # 3. Train a model
# CTGAN (Conditional Tabular GAN) is a generative neural network model used to generate synthetic tabular data.
#
# Its principle is to achieve data generation by training a generator network and a discriminator network.
#
# The main parameters of CTGAN include:
#
# * embedding_dim: embedding dimension, used to convert discrete features into continuous vector representation.
# * generator_dim: the hidden layer dimension of the generator network.
# * discriminator_dim: the hidden layer dimension of the discriminator network.
# * generator_lr: The learning rate of the generator network.
# * discriminator_lr: The learning rate of the discriminator network.
# *batch_size: The number of samples in each training batch.
# * epochs: The number of iterations of training.
#
# The significance of these parameters is to adjust the performance of the model and the stability of the training process. A larger embedding dimension can improve the representation ability of discrete features, while a larger hidden layer dimension can increase the complexity of the network. The learning rate and batch size can affect the convergence speed and stability of the model, while the number of iterations determines the training time of the model.

# %%
# Fit the model
synthesizer.fit()
# Out:
# 2024-12-17 20:25:59.706 | INFO     | sdgx.synthesizer:fit:298 - Fitting data processors...
# 2024-12-17 20:25:59.809 | INFO     | sdgx.data_processors.transformers.specific_combination:fit:70 - Fit data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-12-17 20:25:59.810 | INFO     | sdgx.data_processors.transformers.nan:fit:81 - NonValueTransformer Fitted.
# 2024-12-17 20:25:59.812 | INFO     | sdgx.data_processors.transformers.nan:fit:97 - NonValueTransformer get int columns: {'region', 'early_return_amount_3mon', 'post_code', 'f0', 'title', 'is_default', 'f3', 'marriage', 'early_return_amount', 'year_of_loan', 'f4', 'house_loan_status', 'house_exist', 'offsprings', 'scoring_low', 'censor_status', 'early_return', 'recircle_b', 'initial_list_status', 'f2', 'f1', 'del_in_18month', 'f5', 'scoring_high', 'use', 'pub_dero_bankrup', 'total_loan'}.
# 2024-12-17 20:25:59.813 | INFO     | sdgx.data_processors.transformers.nan:fit:106 - NonValueTransformer get float columns: {'interest', 'monthly_payment', 'debt_loan_ratio', 'recircle_u'}.
# 2024-12-17 20:25:59.814 | INFO     | sdgx.data_processors.transformers.nan:fit:111 - NonValueTransformer get column list from metadata: ['loan_id', 'user_id', 'total_loan', 'year_of_loan', 'interest', 'monthly_payment', 'class', 'sub_class', 'work_type', 'employer_type', 'industry', 'work_year', 'house_exist', 'house_loan_status', 'censor_status', 'marriage', 'offsprings', 'issue_date', 'use', 'post_code', 'region', 'debt_loan_ratio', 'del_in_18month', 'scoring_low', 'scoring_high', 'pub_dero_bankrup', 'early_return', 'early_return_amount', 'early_return_amount_3mon', 'recircle_b', 'recircle_u', 'initial_list_status', 'earlies_credit_mon', 'title', 'policy_code', 'f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'is_default'].
# 2024-12-17 20:25:59.816 | INFO     | sdgx.data_processors.transformers.outlier:fit:76 - OutlierTransformer Fitted.
# 2024-12-17 20:25:59.817 | INFO     | sdgx.data_processors.formatters.int:fit:43 - IntValueFormatter Fitted.
# 2024-12-17 20:25:59.818 | WARNING  | sdgx.data_processors.formatters.datetime:fit:77 - Column issue_date has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-12-17 20:25:59.819 | WARNING  | sdgx.data_processors.formatters.datetime:fit:77 - Column earlies_credit_mon has no datetime_format, DatetimeFormatter will REMOVE this column！
# 2024-12-17 20:25:59.820 | INFO     | sdgx.data_processors.formatters.datetime:fit:90 - DatetimeFormatter Fitted.
# 2024-12-17 20:25:59.821 | INFO     | sdgx.data_processors.transformers.const:fit:53 - ConstValueTransformer Fitted.
# 2024-12-17 20:25:59.822 | INFO     | sdgx.data_processors.filter.positive_negative:fit:58 - PositiveNegativeFilter Fitted.
# 2024-12-17 20:25:59.823 | INFO     | sdgx.data_processors.transformers.empty:fit:57 - EmptyTransformer Fitted.
# 2024-12-17 20:25:59.823 | INFO     | sdgx.data_processors.transformers.column_order:fit:44 - ColumnOrderTransformer Fitted.
# 2024-12-17 20:25:59.824 | INFO     | sdgx.synthesizer:fit:307 - Fitted 12 data processors in  0.014652490615844727s.
# 2024-12-17 20:25:59.824 | INFO     | sdgx.synthesizer:fit:317 - Initializing processed data loader...
# 2024-12-17 20:25:59.834 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-12-17 20:25:59.837 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:167 - Converting data using FixedCombinationTransformer...
# 2024-12-17 20:27:08.132 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:195 - Converting data using FixedCombinationTransformer... Finished.
# 2024-12-17 20:27:08.132 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-12-17 20:27:08.140 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-12-17 20:27:08.141 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-12-17 20:27:08.180 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-12-17 20:27:08.181 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-12-17 20:27:08.181 | INFO     | sdgx.data_processors.formatters.datetime:convert:102 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-12-17 20:27:08.184 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-12-17 20:27:08.187 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-12-17 20:27:08.187 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-12-17 20:27:08.188 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-12-17 20:27:08.188 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-12-17 20:27:08.189 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-12-17 20:27:08.189 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-12-17 20:27:08.209 | INFO     | sdgx.synthesizer:fit:324 - Initialized processed data loader in 68.38467717170715s
# 2024-12-17 20:27:08.210 | INFO     | sdgx.synthesizer:fit:326 - Model fit Started...
# 2024-12-17 20:27:08.217 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-12-17 20:27:08.218 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:162 - Converting data using FixedCombinationTransformer... Finished (No action).
# 2024-12-17 20:27:08.218 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-12-17 20:27:08.225 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-12-17 20:27:08.225 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-12-17 20:27:08.267 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-12-17 20:27:08.267 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-12-17 20:27:08.268 | INFO     | sdgx.data_processors.formatters.datetime:convert:102 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-12-17 20:27:08.270 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-12-17 20:27:08.272 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-12-17 20:27:08.273 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-12-17 20:27:08.273 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-12-17 20:27:08.273 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-12-17 20:27:08.274 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-12-17 20:27:08.274 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-12-17 20:27:08.274 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:241 - Fitting model's transformer...
# 2024-12-17 20:27:08.288 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-12-17 20:27:08.289 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:162 - Converting data using FixedCombinationTransformer... Finished (No action).
# 2024-12-17 20:27:08.289 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-12-17 20:27:08.296 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-12-17 20:27:08.297 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-12-17 20:27:08.336 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-12-17 20:27:08.337 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-12-17 20:27:08.337 | INFO     | sdgx.data_processors.formatters.datetime:convert:102 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-12-17 20:27:08.340 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-12-17 20:27:08.342 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-12-17 20:27:08.342 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-12-17 20:27:08.343 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-12-17 20:27:08.343 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-12-17 20:27:08.344 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-12-17 20:27:08.346 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# Preparing data:  59%|#####8    | 24/41 [00:03<00:02,  7.63it/s]
# 2024-12-17 20:27:15.261 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:243 - Transforming data...
# 2024-12-17 20:27:15.281 | INFO     | sdgx.data_processors.transformers.specific_combination:convert:98 - Converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-12-17 20:27:15.282 | INFO     | sdgx.data_processors.transformers.fixed_combination:convert:162 - Converting data using FixedCombinationTransformer... Finished (No action).
# 2024-12-17 20:27:15.283 | INFO     | sdgx.data_processors.transformers.nan:convert:120 - Converting data using NonValueTransformer...
# 2024-12-17 20:27:15.296 | INFO     | sdgx.data_processors.transformers.nan:convert:140 - Converting data using NonValueTransformer... Finished.
# 2024-12-17 20:27:15.297 | INFO     | sdgx.data_processors.transformers.outlier:convert:90 - Converting data using OutlierTransformer...
# 2024-12-17 20:27:15.358 | INFO     | sdgx.data_processors.transformers.outlier:convert:112 - Converting data using OutlierTransformer... Finished.
# 2024-12-17 20:27:15.359 | INFO     | sdgx.data_processors.formatters.int:convert:53 - Converting data using IntValueFormatter... Finished  (No Action).
# 2024-12-17 20:27:15.359 | INFO     | sdgx.data_processors.formatters.datetime:convert:102 - Converting data using DatetimeFormatter... Finished (No datetime columns).
# 2024-12-17 20:27:15.362 | INFO     | sdgx.data_processors.transformers.const:convert:73 - Converting data using ConstValueTransformer...
# 2024-12-17 20:27:15.364 | INFO     | sdgx.data_processors.transformers.const:convert:81 - Converting data using ConstValueTransformer... Finished.
# 2024-12-17 20:27:15.364 | INFO     | sdgx.data_processors.filter.positive_negative:convert:75 - Converting data using PositiveNegativeFilter... Finished (No Action)
# 2024-12-17 20:27:15.364 | INFO     | sdgx.data_processors.transformers.empty:convert:75 - Converting data using EmptyTransformer...
# 2024-12-17 20:27:15.365 | INFO     | sdgx.data_processors.transformers.empty:convert:79 - Converting data using EmptyTransformer... Finished (No action).
# 2024-12-17 20:27:15.365 | INFO     | sdgx.data_processors.transformers.column_order:convert:54 - Converting data using ColumnOrderTransformer...
# 2024-12-17 20:27:15.366 | INFO     | sdgx.data_processors.transformers.column_order:convert:55 - Converting data using ColumnOrderTransformer... Finished (No action).
# 2024-12-17 20:27:16.473 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:246 - Sampling data.
# 2024-12-17 20:27:16.699 | INFO     | sdgx.models.ml.single_table.ctgan:_pre_fit:251 - Initialize Generator.
# 2024-12-17 20:27:16.705 | INFO     | sdgx.models.ml.single_table.ctgan:fit:224 - CTGAN prefit finished, start CTGAN training.
# 2024-12-17 20:27:16.706 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:263 - Fit using data_size:5939, data_dim: 938.
# 2024-12-17 20:27:16.719 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:289 - Starting model training, epochs: 8
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.42it/s]
# 2024-12-17 20:27:21.216 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 1, Loss G:  3.3102, Loss D: -0.9413, Time:  4.4964
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.52it/s]
# 2024-12-17 20:27:25.587 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 2, Loss G:  2.6172, Loss D: -0.7650, Time:  4.3705
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.51it/s]
# 2024-12-17 20:27:30.043 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 3, Loss G:  2.0373, Loss D: -0.1943, Time:  4.4555
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.45it/s]
# 2024-12-17 20:27:34.516 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 4, Loss G:  2.0157, Loss D:  0.0814, Time:  4.4720
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.45it/s]
# 2024-12-17 20:27:38.980 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 5, Loss G:  1.7904, Loss D:  0.4252, Time:  4.4627
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.52it/s]
# 2024-12-17 20:27:43.350 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 6, Loss G:  2.3208, Loss D: -0.0949, Time:  4.3685
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.50it/s]
# 2024-12-17 20:27:47.745 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 7, Loss G:  2.0995, Loss D:  0.2305, Time:  4.3950
# Fitting batches:  73%|#######2  | 8/11 [00:03<00:01,  2.50it/s]
# 2024-12-17 20:27:52.213 | INFO     | sdgx.models.ml.single_table.ctgan:_fit:369 - Epoch 8, Loss G:  1.9914, Loss D:  0.1677, Time:  4.4672
# 2024-12-17 20:27:52.214 | INFO     | sdgx.models.ml.single_table.ctgan:fit:226 - CTGAN training finished.
# 2024-12-17 20:27:52.216 | INFO     | sdgx.synthesizer:fit:328 - Model fit... Finished

# %% [markdown]
# # 4. Generate synthetic data

# %%
# Sample
real_data = data_loader.load_all()
sampled_data = synthesizer.sample(100)

print(sampled_data)
# Out:
# 2024-12-17 20:27:52.236 | INFO     | sdgx.synthesizer:sample:352 - Sampling...
# Sampling:   0%|          | 0/100 [00:00<?, ?it/s]
# Sampling in batch:  54%|#####3    | 268/500 [00:03<00:02, 88.82it/s]
# Sampling batches: 100%|##########| 1/1 [00:05<00:00,  5.90s/it]
# 2024-12-17 20:27:58.145 | INFO     | sdgx.models.ml.single_table.ctgan:_sample:433 - CTGAN Generated 500 raw samples.
# 2024-12-17 20:27:58.196 | INFO     | sdgx.data_processors.transformers.specific_combination:reverse_convert:117 - Reverse converting data using SpecificCombinationTransformer(No specified)... Finished (No action).
# 2024-12-17 20:27:58.197 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:230 - Reverse converting data using FixedCombinationTransformer...
# 2024-12-17 20:28:12.552 | INFO     | sdgx.data_processors.transformers.fixed_combination:reverse_convert:256 - Reverse converting data using FixedCombinationTransformer... Finished.
# 2024-12-17 20:28:12.552 | INFO     | sdgx.data_processors.transformers.nan:reverse_convert:165 - Data reverse-converted by NonValueTransformer.
# 2024-12-17 20:28:12.554 | INFO     | sdgx.data_processors.transformers.outlier:reverse_convert:126 - Data reverse-converted by OutlierTransformer (No Action).
# 2024-12-17 20:28:12.557 | INFO     | sdgx.data_processors.formatters.int:reverse_convert:69 - Data reverse-converted by IntValueFormatter.
# 2024-12-17 20:28:12.558 | INFO     | sdgx.data_processors.formatters.datetime:reverse_convert:171 - Data reverse-converted by DatetimeFormatter (No datetime columns).
# 2024-12-17 20:28:12.559 | INFO     | sdgx.data_processors.transformers.const:reverse_convert:107 - Data reverse-converted by ConstValueTransformer.
# 2024-12-17 20:28:12.559 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:86 - Data reverse-converted by PositiveNegativeFilter Start with Shape: (500, 42).
# 2024-12-17 20:28:12.562 | INFO     | sdgx.data_processors.filter.positive_negative:reverse_convert:106 - Data reverse-converted by PositiveNegativeFilter with Output Shape: (500, 42).
# 2024-12-17 20:28:12.563 | INFO     | sdgx.data_processors.transformers.column_order:reverse_convert:65 - Data reverse-converted by ColumnOrderTransformer.
#     loan_id  user_id  total_loan  year_of_loan  interest  monthly_payment  \
# 0    488535     1050       10500             3     14.98           255.29
# 1    488535     1050       10500             3     14.98           255.29
# 2    488535     1050       10500             5      7.49           255.29
# 3    488535     1050       10500             3     14.98           255.29
# 4    488535     1050       10500             3     14.98           255.29
# ..      ...      ...         ...           ...       ...              ...
# 95   488535     1050       10500             3      9.99           255.29
# 96   636495      290        4000             3      9.99           128.94
# 97   636495      290        4000             3      8.46           128.94
# 98   488535     1050       10500             3      8.46           255.29
# 99   636495      290        4000             3      7.26           128.94
#
#    class sub_class work_type employer_type  ... earlies_credit_mon title  \
# 0      A        G2       公务员          政府机构  ...           Dec-2003     0
# 1      D        B2        职员          政府机构  ...           Nov-2007     0
# 2      A        C3        工人         世界五百强  ...           Jan-1996     0
# 3      B        B5        其他          普通企业  ...           Jul-2002     0
# 4      A        B5        其他          政府机构  ...           May-1989     0
# ..   ...       ...       ...           ...  ...                ...   ...
# 95     B        C4       公务员          普通企业  ...           Dec-1972     0
# 96     C        C3        其他          普通企业  ...           Feb-2003    10
# 97     B        C3        其他          政府机构  ...           Jun-2008    10
# 98     B        C2        职员       幼教与中小学校  ...           Apr-2001     0
# 99     A        B1       工程师          政府机构  ...           Mar-2004    10
#
#     policy_code  f0  f1  f2  f3  f4  f5  is_default
# 0           1.0  10   0  24  13  37  15           1
# 1           1.0  10   0  24  13  37  15           1
# 2           1.0  13   0  24  13  38  15           1
# 3           1.0  10   0  24  13  37  15           1
# 4           1.0  10   0  24  13  37  15           1
# ..          ...  ..  ..  ..  ..  ..  ..         ...
# 95          1.0  17   0  24  13  41  15           1
# 96          1.0  17   0  47   7  41  13           1
# 97          1.0  16   0  47   7  44  13           1
# 98          1.0  16   0  24  13  44  15           1
# 99          1.0   8   0  47   7  42  13           1
#
# [100 rows x 42 columns]

# %%
sampled_data

# real_data
# Out:
#     loan_id  user_id  total_loan  year_of_loan  interest  monthly_payment  \
# 0    488535     1050       10500             3     14.98           255.29
# 1    488535     1050       10500             3     14.98           255.29
# 2    488535     1050       10500             5      7.49           255.29
# 3    488535     1050       10500             3     14.98           255.29
# 4    488535     1050       10500             3     14.98           255.29
# ..      ...      ...         ...           ...       ...              ...
# 95   488535     1050       10500             3      9.99           255.29
# 96   636495      290        4000             3      9.99           128.94
# 97   636495      290        4000             3      8.46           128.94
# 98   488535     1050       10500             3      8.46           255.29
# 99   636495      290        4000             3      7.26           128.94
#
#    class sub_class work_type employer_type  ... earlies_credit_mon title  \
# 0      A        G2       公务员          政府机构  ...           Dec-2003     0
# 1      D        B2        职员          政府机构  ...           Nov-2007     0
# 2      A        C3        工人         世界五百强  ...           Jan-1996     0
# 3      B        B5        其他          普通企业  ...           Jul-2002     0
# 4      A        B5        其他          政府机构  ...           May-1989     0
# ..   ...       ...       ...           ...  ...                ...   ...
# 95     B        C4       公务员          普通企业  ...           Dec-1972     0
# 96     C        C3        其他          普通企业  ...           Feb-2003    10
# 97     B        C3        其他          政府机构  ...           Jun-2008    10
# 98     B        C2        职员       幼教与中小学校  ...           Apr-2001     0
# 99     A        B1       工程师          政府机构  ...           Mar-2004    10
#
#     policy_code  f0  f1  f2  f3  f4  f5  is_default
# 0           1.0  10   0  24  13  37  15           1
# 1           1.0  10   0  24  13  37  15           1
# 2           1.0  13   0  24  13  38  15           1
# 3           1.0  10   0  24  13  37  15           1
# 4           1.0  10   0  24  13  37  15           1
# ..          ...  ..  ..  ..  ..  ..  ..         ...
# 95          1.0  17   0  24  13  41  15           1
# 96          1.0  17   0  47   7  41  13           1
# 97          1.0  16   0  47   7  44  13           1
# 98          1.0  16   0  24  13  44  15           1
# 99          1.0   8   0  47   7  42  13           1
#
# [100 rows x 42 columns]

# %% [markdown]
# # 5. Data quality assessment on synthetic data
#
# In the field of simulated data, the comparison of the mean and variance of each feature between real data and simulated data is very important:
#
# 1. The mean and variance of real data reflect the data distribution in the real world. By comparing the mean and variance of real and simulated data on each feature, the accuracy and credibility of the simulated data can be evaluated.
#
# 2. The mean and variance are important statistics that describe the center and dispersion of the data set. The mean reflects the central tendency of the data set, and the variance reflects the dispersion of the data set. By comparing the mean and variance of real and simulated data on each feature, you can evaluate whether the simulated data accurately simulates the central tendency and dispersion of the real data.

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import fontManager
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# use table_evaluator for evaluation
from table_evaluator import TableEvaluator

table_evaluator = TableEvaluator(
    real_data[list(set(real_data.columns) - set(loan_metadata.discrete_columns))],
    sampled_data[list(set(real_data.columns) - set(loan_metadata.discrete_columns))])
table_evaluator.plot_mean_std()

# %% [markdown]
# There are 42 columns in the target list. We select some important features for **statistical distribution assessment**.
#
# Through the analysis of these features, we can have a more comprehensive understanding of the borrower's professional status, work experience, industry background, and repayment so as to more accurately assess its loan risk and credit reliability, as follows:
#
# 1. work_type (work type): Indicates the borrower’s work type, such as clerk, worker, other, etc. This characteristic is important in understanding a borrower's professional identity and stability, as different job types may have an impact on a borrower's ability to repay.
#
# 2. work_year (working years): Indicates the borrower’s working years in the current workplace. This feature can reflect the borrower’s work experience and stability. Borrowers who have worked for the same unit for a long time may have greater repayment ability and credit reliability.
#
# 3. Industry: Indicates the industry in which the borrower is located, such as mining, information transmission, finance, etc. Understanding the borrower's industry can help us evaluate the borrower's career stability and industry prospects, and thus determine his or her repayment ability.
#
# 4. monthly_payment (monthly payment amount): Indicates the loan amount that the borrower needs to repay every month. This feature is an important indicator for evaluating the borrower's repayment ability. A higher monthly payment may mean that the borrower has heavier debts and requires higher repayment ability.
#
# 5. post_code (postal code): Indicates the postal code of the borrower's location. Postal codes can provide geographic location information about the borrower's location, which helps us understand the economic conditions and risk profile of the borrower's location.
#
# 6. recircle_b (revolving line usage rate): Indicates the proportion of the revolving line used by the borrower to the total revolving line. Revolving limit refers to a credit card or other credit card that can be used repeatedly. The borrower's utilization rate can reflect his or her credit card usage and repayment habits, which is of great significance for assessing the borrower's credit status and repayment ability.

# %%
target_cols = ['work_type','work_year','industry','monthly_payment',  'post_code',"recircle_b" ]

table_evaluator = TableEvaluator(real_data.loc[:, target_cols], sampled_data.loc[:, target_cols], cat_cols= ["work_year", "work_type", 'industry'])
table_evaluator.plot_distributions(nr_cols=3)
